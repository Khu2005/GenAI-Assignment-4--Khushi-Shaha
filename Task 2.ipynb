# %% [markdown]
# # Task 2

# %%
f=open("sales.txt",'r')
content=f.read()
print(content)
f.close()
# Out:
# 1200
# 450
# 980
# 1500
# 3000

# %%
f=open("sales.txt","r")
sales = [line.strip() for line in f]
print(sales)
f.close()
# Out:
# ['1200', '450', '980', '1500', '3000']

# %%
f=open("sales.txt","r")
sales = f.readlines()
print(list(map(int,sales)))
f.close()
# Out:
# [1200, 450, 980, 1500, 3000]
