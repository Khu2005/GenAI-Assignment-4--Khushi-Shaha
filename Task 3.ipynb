# %% [markdown]
# # Task 3

# %%
f=open("sales.txt","a")
f.write("5000\n")
f.write("2500\n")
f.write("1700\n")
f.close()

# %%
f=open("sales.txt","r")
sales = f.readlines()
print(sales)
f.close()
# Out:
# ['1200\n', '450\n', '980\n', '1500\n', '3000\n', '5000\n', '2500\n', '1700\n']
